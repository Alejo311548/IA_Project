# %%
import pandas as pd
import gdown

# URL de Google Drive del archivo compartido
google_drive_url = 'https://drive.google.com/uc?id=1bdezwlD151pBLVuN2zozy4QZn_ZsuFI_'


# Descargar el archivo desde Google Drive
output_file = 'data.csv'
gdown.download(google_drive_url, output_file, quiet=False)

# Crear un DataFrame a partir del archivo descargado
df = pd.read_csv(output_file, delimiter=',')
df.to_csv('datos_preprocesados.csv', index=False)

# Impresión del dataframe
print(df.head())
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1bdezwlD151pBLVuN2zozy4QZn_ZsuFI_
# To: /content/data.csv
# 100%|██████████| 115M/115M [00:00<00:00, 213MB/s]
#    MUNIC  ZONA  COMUNA   NOMBARRIO           NOMVEREDA  TELEFONO  VIVIENDA  \
# 0      1     1       5  BELALCAZAR  BARRIO ZONA URBANA       1.0       1.0
# 1      1     1       5  BELALCAZAR  BARRIO ZONA URBANA       1.0       1.0
# 2      1     1      16   EL RINCON  BARRIO ZONA URBANA       1.0       1.0
# 3      1     1      16   EL RINCON  BARRIO ZONA URBANA       1.0       1.0
# 4      1     1      16   EL RINCON  BARRIO ZONA URBANA       1.0       1.0
#
#    ENERGIA  ALCANTA  GAS  ...  CARNET  ASISTE  GRADO  NIVEL  ACTIVI  BUSCANDO  \
# 0      1.0      1.0  1.0  ...     4.0     2.0    4.0    1.0     1.0       0.0
# 1      1.0      1.0  1.0  ...     3.0     2.0    4.0    1.0     1.0       0.0
# 2      1.0      1.0  1.0  ...     3.0     2.0    5.0    2.0     4.0       0.0
# 3      1.0      1.0  1.0  ...     3.0     1.0    6.0    2.0     3.0       0.0
# 4      1.0      1.0  1.0  ...     3.0     1.0    1.0    1.0     3.0       0.0
#
#    PERCIBE  INGRESOS  PAGAPOR  PUNTAJE
# 0      2.0       0.0      2.0    38.89
# 1      1.0  500000.0      2.0    38.89
# 2      1.0  600000.0      2.0    57.27
# 3      1.0  680000.0      2.0    57.27
# 4      2.0       0.0      2.0    57.27
#
# [5 rows x 57 columns]

# %%
#stadistic summary
df._get_numeric_data().describe().T
# Out:
#                count           mean            std   min    25%    50%  \
# MUNIC       447871.0       1.000000       0.000000  1.00   1.00   1.00
# ZONA        447871.0       1.144193       0.351813  1.00   1.00   1.00
# COMUNA      447871.0       4.390863       4.361272  0.00   1.00   3.00
# TELEFONO    447871.0       1.141184       0.348211  1.00   1.00   1.00
# VIVIENDA    447871.0       1.040074       0.196236  1.00   1.00   1.00
# ENERGIA     447871.0       1.001061       0.032549  1.00   1.00   1.00
# ALCANTA     447871.0       1.091667       0.288556  1.00   1.00   1.00
# GAS         447871.0       1.654807       0.475432  1.00   1.00   2.00
# BASURA      447871.0       1.003452       0.058651  1.00   1.00   1.00
# ACUEDUC     447871.0       1.033143       0.179011  1.00   1.00   1.00
# ESTRATO     447871.0       1.810407       0.506184  0.00   2.00   2.00
# ELIMBASURA  447871.0       1.008458       0.157230  1.00   1.00   1.00
# TCUARTOSVI  447871.0       3.282168       1.655891  1.00   3.00   3.00
# TELEFONO         1.00        2.00
# VIVIENDA         1.00        3.00
# ENERGIA          1.00        2.00
# ALCANTA          1.00        2.00
# GAS              2.00        2.00
# BASURA           1.00        2.00
# ACUEDUC          1.00        2.00
# ESTRATO          2.00        5.00
# ELIMBASURA       1.00        6.00
# TCUARTOSVI       4.00       74.00
# THOGAR           1.00       20.00
# HOGAR            1.00        8.00
# TENEVIV          3.00        4.00
# TCUARTOS         4.00       13.00
# TDORMIR          3.00       11.00
# SANITAR          1.00        4.00
# TSANITAR         1.00        6.00
# DUCHA            1.00        2.00
# COCINA           1.00        2.00
# COCINAN          3.00        6.00
# ALUMBRA          1.00        4.00
# USOTELE          1.00        2.00
# NEVERA           1.00        2.00
# LAVADORA         2.00        2.00
# TVCOLOR          1.00        2.00
# TVCABLE          2.00        2.00
# CALENTA          2.00        2.00
# HORNO            2.00        2.00
# AIRE             2.00        2.00
# COMPUTADOR       2.00        2.00
# EQUIPO           2.00        2.00
# MOTO             2.00        2.00
# AUTO1            2.00        2.00
# BIERAICES        2.00        2.00
# TPERSONA         6.00       31.00
# TIPODOC          2.00        8.00
# PARENTES         3.00       17.00
# ESTCIVIL         5.00        5.00
# HIJOSDE          0.00       25.00
# SEXO             2.00        2.00
# DISCAPA          0.00        7.00
# CARNET           4.00        4.00
# ASISTE           2.00        2.00
# GRADO            5.00        6.00
# NIVEL            2.00        5.00
# ACTIVI           3.00        7.00
# BUSCANDO         0.00       52.00
# PERCIBE          2.00        2.00
# INGRESOS    100000.00  9000000.00
# PAGAPOR          2.00        2.00
# PUNTAJE         51.34       90.23

# %%
#Distribución de la variable objetivo
import seaborn as sns
sns.distplot(df['PUNTAJE'])
# Out:
# <ipython-input-17-e1efc1c6023e>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['PUNTAJE'])
# <Axes: xlabel='PUNTAJE', ylabel='Density'>

# %%
#Correlación con Pearson
import pandas as pd
import numpy as np

# Cargar el dataset
data = pd.read_csv('datos_preprocesados.csv')

# Calcular la correlación de Pearson con la columna objetivo
correlation_matrix = data.corr()
correlation_with_target = correlation_matrix['PUNTAJE'].abs()

# Ordenar las correlaciones en orden descendente
sorted_correlations = correlation_with_target.sort_values(ascending=False)
print(sorted_correlations)

# Seleccionar las 30 variables más correlacionadas
num_variables_a_mantener = 30
variables_relevantes = sorted_correlations.index[:num_variables_a_mantener]

print(variables_relevantes)
# Out:
# <ipython-input-20-0373dd492640>:9: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data.corr()
# PUNTAJE       1.000000
# ESTRATO       0.352149
# TPERSONA      0.344219
# LAVADORA      0.329305
# ZONA          0.318070
# TCUARTOS      0.307183
# VIVIENDA      0.299863
# NIVEL         0.299811
# ALCANTA       0.285275
# TVCABLE       0.282250
# COMPUTADOR    0.271075
# SANITAR       0.270883
# NEVERA        0.261723
# GRADO         0.257657
# GAS           0.256582
# TELEFONO      0.248966
# HORNO         0.229138
# EQUIPO        0.224590
# TDORMIR       0.211229
# COCINA        0.209659
# CALENTA       0.199708
# INGRESOS      0.195066
# DUCHA         0.188893
# ACUEDUC       0.186207
# THOGAR        0.165095
# TCUARTOSVI    0.162389
# TSANITAR      0.162125
# TIPODOC       0.159893
# MOTO          0.157553
# TVCOLOR       0.151427
# HIJOSDE       0.142096
# PERCIBE       0.139172
# AUTO1         0.132105
# USOTELE       0.130389
# ESTCIVIL      0.127800
# HOGAR         0.126723
# COCINAN       0.120431
# PARENTES      0.113926
# ACTIVI        0.079633
# DISCAPA       0.077668
# BASURA        0.053970
# CARNET        0.051045
# ELIMBASURA    0.050493
# AIRE          0.042774
# TENEVIV       0.042205
# BIERAICES     0.039335
# COMUNA        0.035532
# ENERGIA       0.035097
# SEXO          0.031334
# ALUMBRA       0.030770
# ASISTE        0.020289
# BUSCANDO      0.015261
# PAGAPOR       0.009908
# MUNIC              NaN
# Name: PUNTAJE, dtype: float64
# Index(['PUNTAJE', 'ESTRATO', 'TPERSONA', 'LAVADORA', 'ZONA', 'TCUARTOS',
#        'VIVIENDA', 'NIVEL', 'ALCANTA', 'TVCABLE', 'COMPUTADOR', 'SANITAR',
#        'NEVERA', 'GRADO', 'GAS', 'TELEFONO', 'HORNO', 'EQUIPO', 'TDORMIR',
#        'COCINA', 'CALENTA', 'INGRESOS', 'DUCHA', 'ACUEDUC', 'THOGAR',
#        'TCUARTOSVI', 'TSANITAR', 'TIPODOC', 'MOTO', 'TVCOLOR'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
#Matriz de correlaciones
corr_matrix = df.corr()
#Gráfico de la matriz de correlaciones
plt.figure(figsize=(18,18))
sns.heatmap(corr_matrix, annot = True, vmin = -1, vmax = 1, cmap = "YlGnBu").set_title('Correlation Matrix')
plt.show()
# Out:
# <ipython-input-21-12d5397f9fef>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()

# %%
import pandas as pd


df = pd.read_csv('datos_preprocesados.csv')

# Seleccionar las columnas deseadas
columnas_seleccionadas = ['PUNTAJE', 'ESTRATO', 'TPERSONA', 'LAVADORA', 'ZONA', 'TCUARTOS',
       'VIVIENDA', 'NIVEL', 'ALCANTA', 'TVCABLE', 'COMPUTADOR', 'SANITAR',
       'NEVERA', 'GRADO', 'GAS', 'TELEFONO', 'HORNO', 'EQUIPO', 'TDORMIR',
       'COCINA', 'CALENTA', 'INGRESOS', 'DUCHA', 'ACUEDUC', 'THOGAR',
       'TCUARTOSVI', 'TIPODOC', 'TSANITAR', 'MOTO', 'TVCOLOR']

df_model = df[columnas_seleccionadas]

# Guardar el DataFrame con las columnas seleccionadas en un nuevo archivo CSV
df_model.to_csv('datos_modelo.csv', index=False)

#from google.colab import drive

#drive.mount('/content/drive')
#ruta_guardado = '/content/drive/My Drive/IA_Project/datos_modelo.csv'

# Guarda el DataFrame como un archivo CSV
#df_model.to_csv(ruta_guardado, index=False)

df_model.shape
# Out:
# Mounted at /content/drive
# (447871, 30)

# %%
#Gráficos de los histogramas de las distribuciones de las variables
df_model.hist(bins=50, figsize=(24,15))
plt.suptitle('Histograms For the Different Features', fontsize=16)
plt.show()
